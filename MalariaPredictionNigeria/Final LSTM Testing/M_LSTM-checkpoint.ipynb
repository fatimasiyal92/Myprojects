# %%
import torch
import torch.nn as nn
import torch.optim.lr_scheduler as lr_scheduler

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import os

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
# Input the name of the country for training and testing.
country = 'Nigeria'
# Import the data converted from series format to Time series
df_reframed = pd.read_csv(f'{country}_reshape.csv', index_col='year')
df_reframed.columns
# Out:
# Index(['latnum', 'longnum', 'country', 'dhsregna', 'URBAN_RURA', 'pfir', 'NL',
#        'WD', 'ndvi_1', 'ndvi_2', 'ndvi_3', 'ndvi_4', 'ndvi_5', 'ndvi_6',
#        'ndvi_7', 'ndvi_8', 'ndvi_9', 'ndvi_10', 'ndvi_11', 'ndvi_12', 'rf_1',
#        'rf_2', 'rf_3', 'rf_4', 'rf_5', 'rf_6', 'rf_7', 'rf_8', 'rf_9', 'rf_10',
#        'rf_11', 'rf_12', 't_1', 't_2', 't_3', 't_4', 't_5', 't_6', 't_7',
#        't_8', 't_9', 't_10', 't_11', 't_12', 'next_pfir'],
#       dtype='object')

# %%
# Normalizing the Malaria index columns between 0,1
max = df_reframed.iloc[:,-1].abs().max()
df_rescaled = df_reframed.copy()
df_rescaled.iloc[:,-1] = df_reframed.iloc[:,-1] /max
df_rescaled.iloc[:,-1].abs().max()
df_rescaled.shape
# Out:
# (76176, 45)

# %%
# # Normalizing the Malaria index columns between 0,1
# df_rescaled = df_reframed.copy()
# df_rescaled.iloc[:,-1] = df_reframed.iloc[:,-1]
# df_rescaled.iloc[:,-1].abs()
# df_rescaled.shape

# %%
# Returns number of batches for the total data provided to the function
def getNoOfBatches(batch_size, dataset_size):
    return int(dataset_size/18)
    
# Returns two data frames X:(Features of all Examples reshaped into batches) and Y:(Target of all Examples turned into batches)
def getBatches(df:pd.DataFrame, batch_size=1):
    df_ref = df.values

    Y = df_ref[:, -1]
    Y = Y.reshape(Y.shape[0], 1)
    X = df_ref[:, :df_ref.shape[1]-1]
    # Here batch size indicates the number of timestamps/ No. of years
    no_batches = getNoOfBatches(batch_size = batch_size, dataset_size = X.shape[0])

    X = X.reshape(no_batches, batch_size, X.shape[1])
    Y = Y.reshape(no_batches, batch_size, Y.shape[1])
    return X, Y

# Returns the reshaped features (X) and labels (y)
def get_preprocessed_data(df:pd.DataFrame, batch_size=1):
    X, Y = getBatches(df_reframed, batch_size=18)
    
    X_reshaped = []
    for i in range(X.shape[0]):
        X_reshaped.append(np.delete(X[i], -1, axis=0))
    X_reshaped = np.asarray(X_reshaped)
    
    Y_reshaped = []
    for i in range(Y.shape[0]):
        y=[]
        for j in range(Y.shape[1]):
            if j<17: y.append(Y[i][j+1][0])
        Y_reshaped.append(y)
    
    Y_reshaped = np.asarray(Y_reshaped)
    Y_reshaped = Y_reshaped.reshape(Y_reshaped.shape[0], Y_reshaped.shape[1], 1)
    return X_reshaped, Y_reshaped

# %%
torch.set_default_dtype(torch.double) 

batch_size = 17
dataset_size = df_reframed.shape[0]
example_size = getNoOfBatches(batch_size ,dataset_size)

X_1, Y_1 = get_preprocessed_data(df_reframed, batch_size = batch_size)
# Converting the dtype of X_1, Y_1 from pd.DataFrame to torch.tensor
X_1, Y_1 = torch.tensor(X_1), torch.tensor(Y_1)
print(f'X_1 shape: {X_1.shape} | Y_! shape: {Y_1.shape}')
# Out:
# X_1 shape: torch.Size([4232, 17, 44]) | Y_! shape: torch.Size([4232, 17, 1])

# %%
import random
example_lst = [i for i in range(example_size)]
example_lst = random.sample(example_lst,example_size)

# %%
# Dividing into training and testing datasets
train_split = 0.8
train_values = train_split * example_size
train_values = int(train_values)
train_X, test_X = X_1[example_lst[:train_values],:], X_1[example_lst[train_values:],:]
train_y, test_y = Y_1[example_lst[:train_values], :], Y_1[example_lst[train_values:], :]

# %%
class MultivariateLSTM(nn.Module):
    
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(MultivariateLSTM, self).__init__()

        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc1 = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        
        out, _ = self.lstm(x)
        out = self.fc1(out)
        out = out[:, -1, :]
        return out

# %%
input_size = X_1.shape[-1] # The number of expected features in the input
hidden_size = 100 # The number of hidden states 
num_layers = 4 # Number of Hidden layers
output_size = 1
lr=0.0001

# Initializing a model Object
model = MultivariateLSTM(input_size, hidden_size, num_layers, output_size=1)
# Defining loss function
criterion = nn.L1Loss()
# Selecting an optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Creating a schedular for adaptive learning rate
scheduler = lr_scheduler.LinearLR(optimizer, start_factor=0.3, total_iters=10)

# %%
# Load the model if saved already in params folder
outputs = 0


# increase here
epochs = 500
loss = 0
losses = []
# In case you are loading the model, his variable specifies the number of epochs used in previously
previous_epochs = 0
# Stores count of current epochs plus previous ones
loaded_model_epochs = epochs+previous_epochs

if previous_epochs!=0:
    if os.path.exists('./Saved_Params'):
        loaded_params = torch.load(f'./Saved_Params/{country}_{str(loaded_model_epochs)}_{str(num_layers)}_{str(hidden_size)}_ep_trained.pt')
    else:
        os.mkdir('./Saved_Params')
        loaded_params = torch.load(f'./Saved_Params/{country}_{str(loaded_model_epochs)}_{str(num_layers)}_{str(hidden_size)}_ep_trained.pt')
    
    previous_epochs = loaded_params['checkpoint_epoch']
    loaded_loss = loaded_params['checkpoint_loss']
    loaded_model = loaded_params['model_state_dict']
    loaded_optimizer = loaded_params['optim_state_dict']

    loss = loaded_loss
    model.load_state_dict(loaded_model)
    optimizer.load_state_dict(loaded_optimizer)

# %%
print('Training...LSTM')

# increase Epoch to 10

epochs = [i+1 for i in range(epochs)]
for epoch in epochs:
    train_loss = 0.0
    for i in range(train_X.shape[0]):
        
        input_batch, target_batch = train_X[i], train_y[i]
        input_batch = input_batch.reshape(-1, input_batch.shape[0], input_batch.shape[1])
        
        outputs = model(input_batch)[0]
        target = target_batch[-1]
        loss = criterion(outputs, target)
        optimizer.zero_grad()
        
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * input_batch.size(0)
    scheduler.step()
    
    train_loss /= train_X.shape[0]
    losses.append(train_loss)  
    if epoch%1 == 0: print(f'Epoch {epoch+previous_epochs}/{previous_epochs+epochs[-1]}, Train Loss: {train_loss:.6f}')
epochs = len(epochs)
print('Training Ended!')
# Out:
# Training...LSTM
# Epoch 1/500, Train Loss: 0.076892
# Epoch 2/500, Train Loss: 0.068539
# Epoch 3/500, Train Loss: 0.067293
# Epoch 4/500, Train Loss: 0.065551
# Epoch 5/500, Train Loss: 0.063216
# Epoch 6/500, Train Loss: 0.060434
# Epoch 7/500, Train Loss: 0.060853
# Epoch 8/500, Train Loss: 0.059220
# Epoch 9/500, Train Loss: 0.060341
# Epoch 10/500, Train Loss: 0.058350
# Epoch 11/500, Train Loss: 0.059222
# Epoch 12/500, Train Loss: 0.058114
# Epoch 13/500, Train Loss: 0.059434
# Epoch 14/500, Train Loss: 0.058073
# Epoch 15/500, Train Loss: 0.055612
# Epoch 16/500, Train Loss: 0.054702
# Epoch 17/500, Train Loss: 0.059732
# Epoch 18/500, Train Loss: 0.057928
# Epoch 19/500, Train Loss: 0.053877
# Epoch 20/500, Train Loss: 0.053014
# Epoch 21/500, Train Loss: 0.054604
# Epoch 22/500, Train Loss: 0.056885
# Epoch 23/500, Train Loss: 0.053001
# Epoch 24/500, Train Loss: 0.051924
# Epoch 25/500, Train Loss: 0.050663
# Epoch 26/500, Train Loss: 0.052139
# Epoch 27/500, Train Loss: 0.050036
# Epoch 28/500, Train Loss: 0.050371
# Epoch 29/500, Train Loss: 0.050019
# Epoch 30/500, Train Loss: 0.049349
# Epoch 31/500, Train Loss: 0.047492
# Epoch 32/500, Train Loss: 0.048717
# Epoch 33/500, Train Loss: 0.050901
# Epoch 34/500, Train Loss: 0.046740
# Epoch 35/500, Train Loss: 0.047446
# Epoch 36/500, Train Loss: 0.048549
# Epoch 37/500, Train Loss: 0.046196
# Epoch 38/500, Train Loss: 0.044836
# Epoch 39/500, Train Loss: 0.044317
# Epoch 40/500, Train Loss: 0.046577
# Epoch 41/500, Train Loss: 0.046766
# Epoch 42/500, Train Loss: 0.046955
# Epoch 43/500, Train Loss: 0.046206
# Epoch 44/500, Train Loss: 0.044263
# Epoch 45/500, Train Loss: 0.045375
# Epoch 46/500, Train Loss: 0.042201
# Epoch 47/500, Train Loss: 0.043387
# Epoch 48/500, Train Loss: 0.042345
# Epoch 49/500, Train Loss: 0.045164
# Epoch 50/500, Train Loss: 0.045887
# Epoch 51/500, Train Loss: 0.043573
# Epoch 52/500, Train Loss: 0.041930
# Epoch 53/500, Train Loss: 0.043199
# Epoch 54/500, Train Loss: 0.043219
# Epoch 55/500, Train Loss: 0.041236
# Epoch 56/500, Train Loss: 0.043485
# Epoch 57/500, Train Loss: 0.041710
# Epoch 58/500, Train Loss: 0.042431
# Epoch 59/500, Train Loss: 0.041297
# Epoch 60/500, Train Loss: 0.042424
# Epoch 61/500, Train Loss: 0.040556
# Epoch 62/500, Train Loss: 0.039250
# Epoch 63/500, Train Loss: 0.040508
# Epoch 64/500, Train Loss: 0.040893
# Epoch 65/500, Train Loss: 0.038259
# Epoch 66/500, Train Loss: 0.039062
# Epoch 67/500, Train Loss: 0.042093
# Epoch 68/500, Train Loss: 0.041253
# Epoch 69/500, Train Loss: 0.038435
# Epoch 70/500, Train Loss: 0.040613
# Epoch 71/500, Train Loss: 0.039555
# Epoch 72/500, Train Loss: 0.038569
# Epoch 73/500, Train Loss: 0.039313
# Epoch 74/500, Train Loss: 0.040262
# Epoch 75/500, Train Loss: 0.039499
# Epoch 76/500, Train Loss: 0.036983
# Epoch 77/500, Train Loss: 0.037966
# Epoch 78/500, Train Loss: 0.036996
# Epoch 79/500, Train Loss: 0.038054
# Epoch 80/500, Train Loss: 0.037864
# Epoch 81/500, Train Loss: 0.036959
# Epoch 82/500, Train Loss: 0.035386
# Epoch 83/500, Train Loss: 0.035174
# Epoch 84/500, Train Loss: 0.036315
# Epoch 85/500, Train Loss: 0.036202
# Epoch 86/500, Train Loss: 0.034692
# Epoch 87/500, Train Loss: 0.034433
# Epoch 88/500, Train Loss: 0.034367
# Epoch 89/500, Train Loss: 0.034573
# Epoch 90/500, Train Loss: 0.038844
# Epoch 91/500, Train Loss: 0.038733
# Epoch 92/500, Train Loss: 0.035724
# Epoch 93/500, Train Loss: 0.036175
# Epoch 94/500, Train Loss: 0.037554
# Epoch 95/500, Train Loss: 0.033328
# Epoch 96/500, Train Loss: 0.033410
# Epoch 97/500, Train Loss: 0.034090
# Epoch 98/500, Train Loss: 0.036039
# Epoch 99/500, Train Loss: 0.035259
# Epoch 100/500, Train Loss: 0.036590
# Epoch 101/500, Train Loss: 0.032948
# Epoch 102/500, Train Loss: 0.033505
# Epoch 103/500, Train Loss: 0.033840
# Epoch 104/500, Train Loss: 0.032758
# Epoch 105/500, Train Loss: 0.034588
# Epoch 106/500, Train Loss: 0.032752
# Epoch 107/500, Train Loss: 0.032596
# Epoch 108/500, Train Loss: 0.036524
# Epoch 109/500, Train Loss: 0.036506
# Epoch 110/500, Train Loss: 0.036017
# Epoch 111/500, Train Loss: 0.034657
# Epoch 112/500, Train Loss: 0.034343
# Epoch 113/500, Train Loss: 0.034411
# Epoch 114/500, Train Loss: 0.034254
# Epoch 115/500, Train Loss: 0.033901
# Epoch 116/500, Train Loss: 0.031439
# Epoch 117/500, Train Loss: 0.035432
# Epoch 118/500, Train Loss: 0.032520
# Epoch 119/500, Train Loss: 0.031665
# Epoch 120/500, Train Loss: 0.031378
# Epoch 121/500, Train Loss: 0.029861
# Epoch 122/500, Train Loss: 0.031029
# Epoch 123/500, Train Loss: 0.032680
# Epoch 124/500, Train Loss: 0.034745
# Epoch 125/500, Train Loss: 0.032956
# Epoch 126/500, Train Loss: 0.030545
# Epoch 127/500, Train Loss: 0.032279
# Epoch 128/500, Train Loss: 0.030217
# Epoch 129/500, Train Loss: 0.030661
# Epoch 130/500, Train Loss: 0.030627
# Epoch 131/500, Train Loss: 0.030143
# Epoch 132/500, Train Loss: 0.028559
# Epoch 133/500, Train Loss: 0.029451
# Epoch 134/500, Train Loss: 0.030789
# Epoch 135/500, Train Loss: 0.030031
# Epoch 136/500, Train Loss: 0.033112
# Epoch 137/500, Train Loss: 0.029630
# Epoch 138/500, Train Loss: 0.029621
# Epoch 139/500, Train Loss: 0.030409
# Epoch 140/500, Train Loss: 0.030478
# Epoch 141/500, Train Loss: 0.028419
# Epoch 142/500, Train Loss: 0.028839
# Epoch 143/500, Train Loss: 0.029870
# Epoch 144/500, Train Loss: 0.027416
# Epoch 145/500, Train Loss: 0.027760
# Epoch 146/500, Train Loss: 0.028284
# Epoch 147/500, Train Loss: 0.029180
# Epoch 148/500, Train Loss: 0.028315
# Epoch 149/500, Train Loss: 0.026804
# Epoch 150/500, Train Loss: 0.028293
# Epoch 151/500, Train Loss: 0.027060
# Epoch 152/500, Train Loss: 0.027183
# Epoch 153/500, Train Loss: 0.029100
# Epoch 154/500, Train Loss: 0.027574
# Epoch 155/500, Train Loss: 0.027236
# Epoch 156/500, Train Loss: 0.026924
# Epoch 157/500, Train Loss: 0.026877
# Epoch 158/500, Train Loss: 0.027603
# Epoch 159/500, Train Loss: 0.028239
# Epoch 160/500, Train Loss: 0.028011
# Epoch 161/500, Train Loss: 0.028333
# Epoch 162/500, Train Loss: 0.026584
# Epoch 163/500, Train Loss: 0.026465
# Epoch 164/500, Train Loss: 0.026711
# Epoch 165/500, Train Loss: 0.026954
# Epoch 166/500, Train Loss: 0.026168
# Epoch 167/500, Train Loss: 0.027730
# Epoch 168/500, Train Loss: 0.027405
# Epoch 169/500, Train Loss: 0.025521
# Epoch 170/500, Train Loss: 0.026235
# Epoch 171/500, Train Loss: 0.028215
# Epoch 172/500, Train Loss: 0.025799
# Epoch 173/500, Train Loss: 0.026570
# Epoch 174/500, Train Loss: 0.025737
# Epoch 175/500, Train Loss: 0.027895
# Epoch 176/500, Train Loss: 0.025619
# Epoch 177/500, Train Loss: 0.025251
# Epoch 178/500, Train Loss: 0.025438
# Epoch 179/500, Train Loss: 0.024350
# Epoch 180/500, Train Loss: 0.024952
# Epoch 181/500, Train Loss: 0.025193
# Epoch 182/500, Train Loss: 0.024921
# Epoch 183/500, Train Loss: 0.024062
# Epoch 184/500, Train Loss: 0.025561
# Epoch 185/500, Train Loss: 0.023644
# Epoch 186/500, Train Loss: 0.025878
# Epoch 187/500, Train Loss: 0.024858
# Epoch 188/500, Train Loss: 0.024830
# Epoch 189/500, Train Loss: 0.025662
# Epoch 190/500, Train Loss: 0.025346
# Epoch 191/500, Train Loss: 0.023660
# Epoch 192/500, Train Loss: 0.024264
# Epoch 193/500, Train Loss: 0.024447
# Epoch 194/500, Train Loss: 0.023137
# Epoch 195/500, Train Loss: 0.023766
# Epoch 196/500, Train Loss: 0.022966
# Epoch 197/500, Train Loss: 0.024226
# Epoch 198/500, Train Loss: 0.024462
# Epoch 199/500, Train Loss: 0.024645
# Epoch 200/500, Train Loss: 0.024224
# Epoch 201/500, Train Loss: 0.023931
# Epoch 202/500, Train Loss: 0.023630
# Epoch 203/500, Train Loss: 0.025545
# Epoch 204/500, Train Loss: 0.023174
# Epoch 205/500, Train Loss: 0.023757
# Epoch 206/500, Train Loss: 0.023919
# Epoch 207/500, Train Loss: 0.023597
# Epoch 208/500, Train Loss: 0.022638
# Epoch 209/500, Train Loss: 0.023342
# Epoch 210/500, Train Loss: 0.023607
# Epoch 211/500, Train Loss: 0.023499
# Epoch 212/500, Train Loss: 0.024037
# Epoch 213/500, Train Loss: 0.023255
# Epoch 214/500, Train Loss: 0.023288
# Epoch 215/500, Train Loss: 0.023393
# Epoch 216/500, Train Loss: 0.022579
# Epoch 217/500, Train Loss: 0.023166
# Epoch 218/500, Train Loss: 0.023758
# Epoch 219/500, Train Loss: 0.022623
# Epoch 220/500, Train Loss: 0.023421
# Epoch 221/500, Train Loss: 0.021305
# Epoch 222/500, Train Loss: 0.022158
# Epoch 223/500, Train Loss: 0.023633
# Epoch 224/500, Train Loss: 0.023534
# Epoch 225/500, Train Loss: 0.021824
# Epoch 226/500, Train Loss: 0.021322
# Epoch 227/500, Train Loss: 0.022603
# Epoch 228/500, Train Loss: 0.023085
# Epoch 229/500, Train Loss: 0.021069
# Epoch 230/500, Train Loss: 0.022710
# Epoch 231/500, Train Loss: 0.022462
# Epoch 232/500, Train Loss: 0.021328
# Epoch 233/500, Train Loss: 0.021947
# Epoch 234/500, Train Loss: 0.022985
# Epoch 235/500, Train Loss: 0.021640
# Epoch 236/500, Train Loss: 0.022305
# Epoch 237/500, Train Loss: 0.022332
# Epoch 238/500, Train Loss: 0.022312
# Epoch 239/500, Train Loss: 0.022087
# Epoch 240/500, Train Loss: 0.022004
# Epoch 241/500, Train Loss: 0.021976
# Epoch 242/500, Train Loss: 0.021485
# Epoch 243/500, Train Loss: 0.021327
# Epoch 244/500, Train Loss: 0.021857
# Epoch 245/500, Train Loss: 0.020666
# Epoch 246/500, Train Loss: 0.020521
# Epoch 247/500, Train Loss: 0.020611
# Epoch 248/500, Train Loss: 0.020114
# Epoch 249/500, Train Loss: 0.020308
# Epoch 250/500, Train Loss: 0.022261
# Epoch 251/500, Train Loss: 0.020631
# Epoch 252/500, Train Loss: 0.019795
# Epoch 253/500, Train Loss: 0.020498
# Epoch 254/500, Train Loss: 0.020114
# Epoch 255/500, Train Loss: 0.020978
# Epoch 256/500, Train Loss: 0.023006
# Epoch 257/500, Train Loss: 0.021405
# Epoch 258/500, Train Loss: 0.020398
# Epoch 259/500, Train Loss: 0.019886
# Epoch 260/500, Train Loss: 0.021745
# Epoch 261/500, Train Loss: 0.021363
# Epoch 262/500, Train Loss: 0.021202
# Epoch 263/500, Train Loss: 0.021765
# Epoch 264/500, Train Loss: 0.019907
# Epoch 265/500, Train Loss: 0.020036
# Epoch 266/500, Train Loss: 0.019951
# Epoch 267/500, Train Loss: 0.019985
# Epoch 268/500, Train Loss: 0.019369
# Epoch 269/500, Train Loss: 0.020363
# Epoch 270/500, Train Loss: 0.021455
# Epoch 271/500, Train Loss: 0.020705
# Epoch 272/500, Train Loss: 0.019641
# Epoch 273/500, Train Loss: 0.020343
# Epoch 274/500, Train Loss: 0.020268
# Epoch 275/500, Train Loss: 0.019979
# Epoch 276/500, Train Loss: 0.018908
# Epoch 277/500, Train Loss: 0.019698
# Epoch 278/500, Train Loss: 0.020100
# Epoch 279/500, Train Loss: 0.020223
# Epoch 280/500, Train Loss: 0.019027
# Epoch 281/500, Train Loss: 0.018668
# Epoch 282/500, Train Loss: 0.020070
# Epoch 283/500, Train Loss: 0.019151
# Epoch 284/500, Train Loss: 0.018965
# Epoch 285/500, Train Loss: 0.019414
# Epoch 286/500, Train Loss: 0.019761
# Epoch 287/500, Train Loss: 0.020412
# Epoch 288/500, Train Loss: 0.020767
# Epoch 289/500, Train Loss: 0.018400
# Epoch 290/500, Train Loss: 0.018445
# Epoch 291/500, Train Loss: 0.019240
# Epoch 292/500, Train Loss: 0.019439
# Epoch 293/500, Train Loss: 0.020155
# Epoch 294/500, Train Loss: 0.018522
# Epoch 295/500, Train Loss: 0.018719
# Epoch 296/500, Train Loss: 0.019200
# Epoch 297/500, Train Loss: 0.019735
# Epoch 298/500, Train Loss: 0.019666
# Epoch 299/500, Train Loss: 0.018502
# Epoch 300/500, Train Loss: 0.018715
# Epoch 301/500, Train Loss: 0.020405
# Epoch 302/500, Train Loss: 0.018508
# Epoch 303/500, Train Loss: 0.017832
# Epoch 304/500, Train Loss: 0.019487
# Epoch 305/500, Train Loss: 0.018562
# Epoch 306/500, Train Loss: 0.018518
# Epoch 307/500, Train Loss: 0.018788
# Epoch 308/500, Train Loss: 0.018863
# Epoch 309/500, Train Loss: 0.019268
# Epoch 310/500, Train Loss: 0.019632
# Epoch 311/500, Train Loss: 0.019314
# Epoch 312/500, Train Loss: 0.018376
# Epoch 313/500, Train Loss: 0.020229
# Epoch 314/500, Train Loss: 0.018032
# Epoch 315/500, Train Loss: 0.017482
# Epoch 316/500, Train Loss: 0.018165
# Epoch 317/500, Train Loss: 0.017535
# Epoch 318/500, Train Loss: 0.018490
# Epoch 319/500, Train Loss: 0.018030
# Epoch 320/500, Train Loss: 0.017495
# Epoch 321/500, Train Loss: 0.017347
# Epoch 322/500, Train Loss: 0.017439
# Epoch 323/500, Train Loss: 0.016811
# Epoch 324/500, Train Loss: 0.017113
# Epoch 325/500, Train Loss: 0.018947
# Epoch 326/500, Train Loss: 0.017738
# Epoch 327/500, Train Loss: 0.017155
# Epoch 328/500, Train Loss: 0.017133
# Epoch 329/500, Train Loss: 0.016736
# Epoch 330/500, Train Loss: 0.017741
# Epoch 331/500, Train Loss: 0.019222
# Epoch 332/500, Train Loss: 0.016936
# Epoch 333/500, Train Loss: 0.017495
# Epoch 334/500, Train Loss: 0.017414
# Epoch 335/500, Train Loss: 0.017193
# Epoch 336/500, Train Loss: 0.015990
# Epoch 337/500, Train Loss: 0.017023
# Epoch 338/500, Train Loss: 0.016964
# Epoch 339/500, Train Loss: 0.017598
# Epoch 340/500, Train Loss: 0.016701
# Epoch 341/500, Train Loss: 0.017677
# Epoch 342/500, Train Loss: 0.018022
# Epoch 343/500, Train Loss: 0.017226
# Epoch 344/500, Train Loss: 0.016560
# Epoch 345/500, Train Loss: 0.016939
# Epoch 346/500, Train Loss: 0.016308
# Epoch 347/500, Train Loss: 0.016462
# Epoch 348/500, Train Loss: 0.017325
# Epoch 349/500, Train Loss: 0.018726
# Epoch 350/500, Train Loss: 0.017959
# Epoch 351/500, Train Loss: 0.017689
# Epoch 352/500, Train Loss: 0.017350
# Epoch 353/500, Train Loss: 0.017173
# Epoch 354/500, Train Loss: 0.017482
# Epoch 355/500, Train Loss: 0.017095
# Epoch 356/500, Train Loss: 0.017208
# Epoch 357/500, Train Loss: 0.017150
# Epoch 358/500, Train Loss: 0.017921
# Epoch 359/500, Train Loss: 0.017220
# Epoch 360/500, Train Loss: 0.016864
# Epoch 361/500, Train Loss: 0.016146
# Epoch 362/500, Train Loss: 0.018479
# Epoch 363/500, Train Loss: 0.017540
# Epoch 364/500, Train Loss: 0.018119
# Epoch 365/500, Train Loss: 0.017398
# Epoch 366/500, Train Loss: 0.018348
# Epoch 367/500, Train Loss: 0.017377
# Epoch 368/500, Train Loss: 0.017020
# Epoch 369/500, Train Loss: 0.017358
# Epoch 370/500, Train Loss: 0.016572
# Epoch 371/500, Train Loss: 0.017326
# Epoch 372/500, Train Loss: 0.016603
# Epoch 373/500, Train Loss: 0.016137
# Epoch 374/500, Train Loss: 0.016235
# Epoch 375/500, Train Loss: 0.017528
# Epoch 376/500, Train Loss: 0.017763
# Epoch 377/500, Train Loss: 0.016221
# Epoch 378/500, Train Loss: 0.016281
# Epoch 379/500, Train Loss: 0.015853
# Epoch 380/500, Train Loss: 0.016726
# Epoch 381/500, Train Loss: 0.016873
# Epoch 382/500, Train Loss: 0.016932
# Epoch 383/500, Train Loss: 0.015908
# Epoch 384/500, Train Loss: 0.016293
# Epoch 385/500, Train Loss: 0.016549
# Epoch 386/500, Train Loss: 0.017023
# Epoch 387/500, Train Loss: 0.016170
# Epoch 388/500, Train Loss: 0.016862
# Epoch 389/500, Train Loss: 0.015162
# Epoch 390/500, Train Loss: 0.015312
# Epoch 391/500, Train Loss: 0.015371
# Epoch 392/500, Train Loss: 0.016094
# Epoch 393/500, Train Loss: 0.015768
# Epoch 394/500, Train Loss: 0.016292
# Epoch 395/500, Train Loss: 0.016228
# Epoch 396/500, Train Loss: 0.017973
# Epoch 397/500, Train Loss: 0.016215
# Epoch 398/500, Train Loss: 0.016534
# Epoch 399/500, Train Loss: 0.016128
# Epoch 400/500, Train Loss: 0.016648
# Epoch 401/500, Train Loss: 0.015155
# Epoch 402/500, Train Loss: 0.016631
# Epoch 403/500, Train Loss: 0.016282
# Epoch 404/500, Train Loss: 0.016513
# Epoch 405/500, Train Loss: 0.015172
# Epoch 406/500, Train Loss: 0.016149
# Epoch 407/500, Train Loss: 0.016082
# Epoch 408/500, Train Loss: 0.015988
# Epoch 409/500, Train Loss: 0.016393
# Epoch 410/500, Train Loss: 0.014684
# Epoch 411/500, Train Loss: 0.016227
# Epoch 412/500, Train Loss: 0.014980
# Epoch 413/500, Train Loss: 0.015577
# Epoch 414/500, Train Loss: 0.016164
# Epoch 415/500, Train Loss: 0.015544
# Epoch 416/500, Train Loss: 0.015387
# Epoch 417/500, Train Loss: 0.015257
# Epoch 418/500, Train Loss: 0.015338
# Epoch 419/500, Train Loss: 0.015528
# Epoch 420/500, Train Loss: 0.015865
# Epoch 421/500, Train Loss: 0.015273
# Epoch 422/500, Train Loss: 0.014077
# Epoch 423/500, Train Loss: 0.015653
# Epoch 424/500, Train Loss: 0.015211
# Epoch 425/500, Train Loss: 0.014647
# Epoch 426/500, Train Loss: 0.014054
# Epoch 427/500, Train Loss: 0.014340
# Epoch 428/500, Train Loss: 0.015144
# Epoch 429/500, Train Loss: 0.015166
# Epoch 430/500, Train Loss: 0.014973
# Epoch 431/500, Train Loss: 0.014846
# Epoch 432/500, Train Loss: 0.014910
# Epoch 433/500, Train Loss: 0.014698
# Epoch 434/500, Train Loss: 0.014924
# Epoch 435/500, Train Loss: 0.014392
# Epoch 436/500, Train Loss: 0.014519
# Epoch 437/500, Train Loss: 0.014398
# Epoch 438/500, Train Loss: 0.014635
# Epoch 439/500, Train Loss: 0.014883
# Epoch 440/500, Train Loss: 0.014049
# Epoch 441/500, Train Loss: 0.014576
# Epoch 442/500, Train Loss: 0.015023
# Epoch 443/500, Train Loss: 0.014598
# Epoch 444/500, Train Loss: 0.015256
# Epoch 445/500, Train Loss: 0.015074
# Epoch 446/500, Train Loss: 0.014248
# Epoch 447/500, Train Loss: 0.014124
# Epoch 448/500, Train Loss: 0.015515
# Epoch 449/500, Train Loss: 0.015672
# Epoch 450/500, Train Loss: 0.014497
# Epoch 451/500, Train Loss: 0.014765
# Epoch 452/500, Train Loss: 0.013963
# Epoch 453/500, Train Loss: 0.014409
# Epoch 454/500, Train Loss: 0.014396
# Epoch 455/500, Train Loss: 0.013595
# Epoch 456/500, Train Loss: 0.014814
# Epoch 457/500, Train Loss: 0.014627
# Epoch 458/500, Train Loss: 0.013900
# Epoch 459/500, Train Loss: 0.014818
# Epoch 460/500, Train Loss: 0.014260
# Epoch 461/500, Train Loss: 0.014639
# Epoch 462/500, Train Loss: 0.014872
# Epoch 463/500, Train Loss: 0.014678
# Epoch 464/500, Train Loss: 0.015149
# Epoch 465/500, Train Loss: 0.014324
# Epoch 466/500, Train Loss: 0.014179
# Epoch 467/500, Train Loss: 0.013907
# Epoch 468/500, Train Loss: 0.013595
# Epoch 469/500, Train Loss: 0.013765
# Epoch 470/500, Train Loss: 0.014064
# Epoch 471/500, Train Loss: 0.014737
# Epoch 472/500, Train Loss: 0.014117
# Epoch 473/500, Train Loss: 0.015372
# Epoch 474/500, Train Loss: 0.015129
# Epoch 475/500, Train Loss: 0.013722
# Epoch 476/500, Train Loss: 0.014195
# Epoch 477/500, Train Loss: 0.014198
# Epoch 478/500, Train Loss: 0.013445
# Epoch 479/500, Train Loss: 0.013876
# Epoch 480/500, Train Loss: 0.013781
# Epoch 481/500, Train Loss: 0.013852
# Epoch 482/500, Train Loss: 0.014616
# Epoch 483/500, Train Loss: 0.013877
# Epoch 484/500, Train Loss: 0.013336
# Epoch 485/500, Train Loss: 0.014348
# Epoch 486/500, Train Loss: 0.014155
# Epoch 487/500, Train Loss: 0.014113
# Epoch 488/500, Train Loss: 0.013940
# Epoch 489/500, Train Loss: 0.014545
# Epoch 490/500, Train Loss: 0.013403
# Epoch 491/500, Train Loss: 0.014052
# Epoch 492/500, Train Loss: 0.014175
# Epoch 493/500, Train Loss: 0.013963
# Epoch 494/500, Train Loss: 0.013424
# Epoch 495/500, Train Loss: 0.014515
# Epoch 496/500, Train Loss: 0.013832
# Epoch 497/500, Train Loss: 0.014903
# Epoch 498/500, Train Loss: 0.014187
# Epoch 499/500, Train Loss: 0.013561
# Epoch 500/500, Train Loss: 0.014027
# Training Ended!

# %%
# Saving the los graph
if os.path.exists('./Graphs/loss/'):
    saved_nm = f'./Graphs/loss/{country}_{str(loaded_model_epochs)}_{str(num_layers)}_{str(hidden_size)}_plot.png'
else:
    os.makedirs('./Graphs/loss')
    saved_nm = f'./Graphs/loss/{country}_{str(loaded_model_epochs)}_{str(num_layers)}_{str(hidden_size)}_plot.png'
epoch_lst = [i+1 for i in range(epochs)]
plt.plot(epoch_lst, losses)
plt.title(f'Loss on {country} over {loaded_model_epochs} epochs using\n {num_layers} LSTM layers | {hidden_size} hidden states')
plt.savefig(saved_nm)
plt.show()

# %%
# Save the Parameters of the trained
if not os.path.exists('./Saved_Params'):
    os.mkdir('./Saved_Params')

torch.save({
    'checkpoint_epoch':loaded_model_epochs,
    'checkpoint_loss': loss,
    'model_state_dict':model.state_dict(),
    'optim_state_dict':optimizer.state_dict()
},f'./Saved_Params/{country}_{str(loaded_model_epochs)}_{str(num_layers)}_{str(hidden_size)}_ep_trained.pt')

loaded_params = torch.load(f'./Saved_Params/{country}_{str(loaded_model_epochs)}_{str(num_layers)}_{str(hidden_size)}_ep_trained.pt')
loaded_model = loaded_params['model_state_dict']
model.eval()
# Out:
# MultivariateLSTM(
#   (lstm): LSTM(44, 100, num_layers=4, batch_first=True)
#   (fc1): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
# Calculating Root mean squared Error!
# def calculate_accuracy(y_true, y_pred, threshold=0.1):
#     correct_predictions = np.abs(y_true - y_pred) <= threshold * np.abs(y_true)
#     accuracy = np.mean(correct_predictions)
#     return accuracy

# # Use the model to generate predictions
# # model.eval()
# y_pred = model(test_X)

# # Convert predictions and actual values to numpy arrays
# y_pred = y_pred.detach().numpy()
# y_true = test_y.numpy()

# # Squeeze y_true to remove unnecessary dimensions
# y_true = np.squeeze(y_true)

# # Now calculate accuracy
# accuracy = calculate_accuracy(y_true, y_pred)
# print(f'Accuracy: {accuracy * 100:.2f}%')

# %%
# Calculating Root mean squared Error!

# Calculating Root mean squared Error!
def calculate_accuracy(y_true, y_pred, threshold=0.1):
    correct_predictions = np.abs(y_true - y_pred) <= threshold * np.abs(y_true)
    accuracy = np.mean(correct_predictions)
    return accuracy

yhat = []
ys = []
with torch.no_grad():
    for i in range(test_X.shape[0]):
        input_batch, target_batch = test_X[i], test_y[i]
        input_batch = input_batch.reshape(1, input_batch.shape[0], input_batch.shape[1])

        outputs = model(input_batch)
        yhat.append(outputs[-1].numpy())
        ys.append(target_batch[-1].numpy())

yhat = np.multiply(yhat ,max)
ys = np.multiply(ys ,max)
tol = 1e-3
count = 0

accuracy = calculate_accuracy(yhat, ys)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 64.94%

# %%
# Compare the actual vs predicted values
if not os.path.exists('./Graphs/actualVspred'):
    os.makedirs('./Graphs/actualVspred')
saved_nm = f'./Graphs/actualVspred/{country}_{str(loaded_model_epochs)}_{str(num_layers)}_{str(hidden_size)}_plot.png'
# previous_epochs
plt.figure(figsize=(20,10))
plt.plot(yhat,'r', label = 'Predicted Malaria index')
plt.plot(ys, 'y', label = 'Actual Malaria Index')
plt.legend()
plt.xlabel('No. of test examples')
plt.ylabel('Malaria Incidence rate')
plt.title(f'Comparison between Prediction and Actual Plot on {loaded_model_epochs} epochs for {country}.\n {num_layers} LSTM layers | {hidden_size} hidden states')
plt.savefig(saved_nm)
plt.show()

# %%
# Reset the Model_log.csv file
def create_new_log():
    df_log = pd.DataFrame(columns = [])
    df_log.to_csv('model_log.csv')
# Uncomment the following to create new log file
create_new_log()

# %%
# Calculating errors for testing set
mae_loss = mean_absolute_error(ys,yhat)
print('Mean Absolute Error = ', mae_loss)

mse_loss = mean_squared_error(ys,yhat)
print('Mean Squared Error = ', mse_loss)

rmse_loss = np.sqrt(mean_squared_error(ys,yhat))
print('Root Mean Squared Error = ', rmse_loss)
# Out:
# Mean Absolute Error =  0.012194523247912929
# Mean Squared Error =  0.00038276743472086884
# Root Mean Squared Error =  0.019564443123198494

# %%
# Updating and creating a log file
# Add a row entry in the model_log.csv file
dict = [{
    'country':country,
    'epochs': loaded_model_epochs,
    'accuracy(%)': accuracy,
    'root_mean_sqr_err': rmse_loss,
    'lstm_units':hidden_size,
    'lstm_layers':num_layers,
}]
df_entry = pd.DataFrame(dict)
# Reading recorded log
df_log = pd.read_csv('model_log.csv', index_col=0)
# Adding to the recorded log
df_log = pd.concat([df_log, df_entry])
df_log.to_csv('model_log.csv')
df_log
# Out:
#    country  epochs  accuracy(%)  root_mean_sqr_err  lstm_units  lstm_layers
# 0  Nigeria     500     0.649351           0.019564         100            4

# %%
# Saving the predicted and actual values for further analysis
test_size = test_X.shape[0]
ser_lst = []
for i in range(test_size):
    ser={
        'latnum':test_X[i][-1][0].item(),
        'longnum':test_X[i][-1][1].item(),
        'actual':ys[i][0],
        'predicted':yhat[i][0]
    }
    ser_lst.append(ser)
df_comp = pd.DataFrame(ser_lst)
if not os.path.exists('./saved_results'):
    os.mkdir('./saved_results')

df_comp.to_csv(f'./saved_results/{country}_{str(loaded_model_epochs)}_{str(num_layers)}_{str(hidden_size)}_actualVsPred.csv')
